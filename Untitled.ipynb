# %%
import numpy as np
import sklearn
import matplotlib.pyplot as plt
import mnist_reader
from sklearn.datasets import fetch_openml
from sklearn.decomposition import PCA

# %%
X_train, y_train = mnist_reader.load_mnist('data/fashion', kind='train')
X_test, y_test = mnist_reader.load_mnist('data/fashion', kind='t10k')

# %%
pca = PCA(n_components=2)
img_pca= pca.fit_transform(X_test.T)

f, (ax1,ax2,ax3) = plt.subplots(1,3)
f.set_size_inches((24,40))
ax1.imshow(img_pca[:,0].reshape((784,1)), cmap=plt.cm.gray)
ax1.set_title("Principal component 1")
ax2.imshow(img_pca[:,1].reshape((784,1)), cmap=plt.cm.gray)
ax2.set_title("Principal component 2")



# pca_test = PCA(n_components=2)
# pca_test.fit(X_test, y_test)
# pca_test.
# Out:
# Text(0.5, 1.0, 'Principal component 2')

# %%
# load the MNIST data
X_mnist, y_mnist = fetch_openml(name='Fashion-MNIST',return_X_y=True)
random.seed(5)
frac_of_dataset = 0.5
index = int(frac_of_dataset*X_mnist.shape[0])
X_train, X_test, y_train, y_test = train_test_split(X_mnist[:index], y_mnist[:index], test_size=0.2)
