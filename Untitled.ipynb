# %%
import numpy as np
import sklearn
import pandas as pd
import matplotlib.pyplot as plt
import mnist_reader #dont really need this perhaps?
import plotly.express as px
from sklearn.datasets import fetch_openml
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.model_selection import learning_curve
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import scale
from sklearn.mixture import GaussianMixture
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import fetch_california_housing
import seaborn as sns

# %%
# load the MNIST data
X_mnist, y_mnist = fetch_openml(name='Fashion-MNIST',return_X_y=True, as_frame=False)
X_train, X_validation, y_train, y_validation = train_test_split(X_mnist, y_mnist, test_size=0.8)

# %%
#https://www.youtube.com/watch?v=oiusrJ0btwA
X = scale(X_mnist) #standardize the data
pca = PCA(n_components=2) #maybe change n_components=2 
pca.fit(X)
# Out:
# PCA(n_components=2)

# %%
scores = pca.transform(X)
scores_df = pd.DataFrame(scores, columns=['PC1', 'PC2'])
scores_df #building the model
# Out:
#              PC1        PC2
# 0      -0.824695  20.862604
# 1      17.073390  -4.966217
# 2      -9.600036 -12.321928
# 3      -0.310827 -11.590370
# 4       8.975907 -12.880551
# ...          ...        ...
# 69995  -5.775710  16.066842
# 69996 -11.615810 -14.296728
# 69997  -6.993530  -8.488647
# 69998  -2.892285 -15.376467
# 69999 -17.532248   0.124833
#
# [70000 rows x 2 columns]

# %%
explained_variance = pca.explained_variance_ratio_
explained_variance
#calculating the values and putting it into a pd framework
pc_df = pd.DataFrame(['', 'PC1', 'PC2', 'PC3'], columns=['PC'])
explained_variance = np.insert(explained_variance, 0, 0)
cumulative_variance = np.cumsum(np.round(explained_variance, decimals=3))
explained_variance_df = pd.DataFrame(explained_variance, columns=['Explained Variance'])
cumulative_variance_df = pd.DataFrame(cumulative_variance, columns=['Cumulative Variance'])
df_explained_variance = pd.concat([pc_df, explained_variance_df, cumulative_variance_df], axis=1)

fig = px.bar(df_explained_variance,
            x='PC', y='Explained Variance',
            text='Explained Variance',
            width=800)
fig.update_traces(texttemplate='%{text:.3f}', textposition='outside') #puts the values outside the bar
fig.show()
# Out:
# <div>                            <div id="32787b71-486a-4c0d-94f5-107609b4a9a4" class="plotly-graph-div" style="height:525px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("32787b71-486a-4c0d-94f5-107609b4a9a4")) {                    Plotly.newPlot(                        "32787b71-486a-4c0d-94f5-107609b4a9a4",                        [{"alignmentgroup":"True","hovertemplate":"PC=%{x}<br>Explained Variance=%{text}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[0.0,0.22092291945404252,0.14402604972489652,null],"textposition":"outside","x":["","PC1","PC2","PC3"],"xaxis":"x","y":[0.0,0.22092291945404252,0.14402604972489652,null],"yaxis":"y","type":"bar","texttemplate":"%{text:.3f}"}],    
# ...

# %%
#2.1.1 q2
pc1_array = np.array(scores_df['PC1'])
pc2_array = np.array(scores_df['PC2'])
plt.figure(figsize=(20,20))
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.scatter(pc1_array, pc2_array, c=pc1_array)
#remember to add points to the data

# %%
#2.1.2
GMM_model = GaussianMixture(n_components=10)
# X = StandardScaler()
# GMM_data = X.fit_transform(scores_df)
GMM_model.fit(np.array(scores_df))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [96], line 5
#       2 GMM_model = GaussianMixture(n_components=10)
#       3 # X = StandardScaler()
#       4 # GMM_data = X.fit_transform(scores_df)
# ----> 5 GMM_model.fit(np.array(scores_df))
#
# File ~\anaconda3\lib\site-packages\sklearn\mixture\_base.py:200, in BaseMixture.fit(self, X, y)
#     174 def fit(self, X, y=None):
#     175     """Estimate model parameters with the EM algorithm.
#     176
#     177     The method fits the model ``n_init`` times and sets the parameters with
#    (...)
#     198         The fitted mixture.
#     199     """
# --> 200     self.fit_predict(X, y)
#     201     return self
#
# File ~\anaconda3\lib\site-packages\sklearn\mixture\_base.py:253, in BaseMixture.fit_predict(self, X, y)
#     250 self._print_verbose_msg_init_beg(init)
#     252 if do_init:
# ...

# %%
X_scaled
# Out:
# array([[ 2.34476576,  0.98214266,  0.62855945, ..., -0.04959654,
#          1.05254828, -1.32783522],
#        [ 2.33223796, -0.60701891,  0.32704136, ..., -0.09251223,
#          1.04318455, -1.32284391],
#        [ 1.7826994 ,  1.85618152,  1.15562047, ..., -0.02584253,
#          1.03850269, -1.33282653],
#        ...,
#        [-1.14259331, -0.92485123, -0.09031802, ..., -0.0717345 ,
#          1.77823747, -0.8237132 ],
#        [-1.05458292, -0.84539315, -0.04021111, ..., -0.09122515,
#          1.77823747, -0.87362627],
#        [-0.78012947, -1.00430931, -0.07044252, ..., -0.04368215,
#          1.75014627, -0.83369581]])

# %%
#2.2.1
X, y = fetch_california_housing(return_X_y=True)
scaler = StandardScaler()
k = scaler.fit(X)
X_scaled = scaler.transform(X)
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2)

# %%
# test_a = data['Latitude']
# test_b = data['Longitude']
# test_c = pd.concat([[test_a], [test_b]])
# pd.DataFrame(test_c)
data_2 = pd.DataFrame(X, columns=feature_names)
plot_2 = sns.pairplot(data)
plot_2

# %%
print(X.shape[0], 'examples')
print(X.shape[1], 'features')
feature_names = fetch_california_housing().feature_names
print(feature_names)

data = pd.DataFrame(X_scaled, columns=feature_names)
data['MedHouseValue'] = y
plot = sns.pairplot(data)
# Out:
# 20640 examples
# 8 features
# ['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup', 'Latitude', 'Longitude']

# %%
data_latitude = data['Latitude']
data_longtitude = data['Longitude']
data_medhousevalue = data['MedHouseValue']
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.set_xlabel("Latitude")
ax.set_ylabel("Longitude")
ax.set_zlabel("MedHouseValue")
ax.scatter3D(data_latitude, data_longtitude, data_medhousevalue)
#https://www.kaggle.com/code/ilialar/california-housing-analysis-and-preciction/notebook

# %%
#2.1
logreg = LogisticRegression()
logreg.fit(X_train, y_train.flatten())
print('w_1 = {:.2f}'.format(logreg.coef_.item()))
print('b = {:.2f}'.format(logreg.intercept_.item()))
# x = learning_curve(X_train, y_train)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [8], line 4
#       2 logreg = LogisticRegression()
#       3 logreg.fit(X_train, y_train.flatten())
# ----> 4 print('w_1 = {:.2f}'.format(logreg.coef_.item()))
#       5 print('b = {:.2f}'.format(logreg.intercept_.item()))
#
# ValueError: can only convert an array of size 1 to a Python scalar

# %%
X_mnist.shape
# Out:
# (70000, 784)

# %%
# Out:
# Text(0.5, 1.0, 'Principal component 2')

# %%
#2.1.2 GMM
GMM_model = GaussianMixture(n_components=10)
# GMM_model.fit(scores_df)
scores_df
features = ['PC1', 'PC2']
X = scores_df[features]
z = StandardScaler()
z.fit(X)
cluster = GMM_model.fit(X)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [31], line 9
#       7 z = StandardScaler()
#       8 z.fit(X)
# ----> 9 cluster = GMM_model.fit(X)
#
# File ~\anaconda3\lib\site-packages\sklearn\mixture\_base.py:200, in BaseMixture.fit(self, X, y)
#     174 def fit(self, X, y=None):
#     175     """Estimate model parameters with the EM algorithm.
#     176
#     177     The method fits the model ``n_init`` times and sets the parameters with
#    (...)
#     198         The fitted mixture.
#     199     """
# --> 200     self.fit_predict(X, y)
#     201     return self
#
# File ~\anaconda3\lib\site-packages\sklearn\mixture\_base.py:253, in BaseMixture.fit_predict(self, X, y)
#     250 self._print_verbose_msg_init_beg(init)
#     252 if do_init:
# --> 253     self._initialize_parameters(X, random_state)
#     255 lower_bound = -np.inf if do_init else self.lower_bound_
# ...

# %%
#2.1.2 GMM
